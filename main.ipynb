# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    else:
        return b
#your code here

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.056s
#
# OK

# %%
#your code here
greater(56,76)
# Out:
# 76

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here
def greatest(a):
    stored = 0
    for i in a:
        if i > stored:
            stored = i
    return stored

# %%
greatest([50,50,47,4874,36,2737])
# Out:
# 4874

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.060s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
#your code here
    total = 0
    for i in lst:
        total += i
    return total

# %%
sum_all([6545,345434,65456,245])
# Out:
# 417680

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.067s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    product = 1      
    for i in lst:
        product *= i
    return product
    #return [product * i for i in lst]
#your code here

# %%
mult_all([1,2,3,4,5])
# Out:
# 120

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.077s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
#your code here
    if oper == "*":
        value = 1      
        for i in arr:
            value *= i
        return value
    else:
        value = 0
        for i in arr:
            value += i
        return value

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.037s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    ans = 1
    i = 1
    
    #Calculating factorial of number
    while (i <= n): #while the iteration is not equal to the number passed
        ans *= i    #multiply answer to the value of the iteration
        i += 1      #then start a new iteration 
    return ans      #when the iteration has the same value of the number passed return the value

def factorial(n):
    if n == 0:
        return 1

    return n * factorial(n - 1)

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.048s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
#your code here
    lst_unique = []
    for elem in lst_un:
        if elem not in lst_unique:
            lst_unique.append(elem)
    return lst_unique

# %%
def unique(lst_un):
#your code here
    lst_unique = []
    for elem in lst_un:
        if elem not in lst_unique:
            lst_unique += [elem]
    return lst_unique

# %%
unique([4,5,6])
# Out:
# [4, 5, 6]

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.176s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    lsts = {}
    for i in arr:
        found = False
        for k in lsts:
            if k == i:
                lsts[k] = lsts[k] +1
                found = True
        if found == False:
            lsts[i] =1
    stored = 0
    winners = []
    for x in lsts:    
        if lsts[x] >= stored:
            winners = [x, lsts[x]]
            stored = lsts[x]
    return winners[0]
#your code here:

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.100s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
    avg = 0.0
    n = 0
    total = 0.0
    var = 0.0
    for i in list_sd:       
        total += i
        n += 1
    avg = total / n
    for i in list_sd:
        var += ((i-avg)**2)/(n-1)

    return var ** 0.5
    
#your code here

# %%
list_sd= [1,2,3,5,6,7,8]
avg = 0
n = 0
total = 0
var = 0
for i in list_sd:
    total += i
    n += 1
avg = total / n
for i in list_sd:
    var += ((i-avg)**2)/(n-1)

print (var ** 0.5)
# Out:
# 2.63673679998231

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.067s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    check = "qwertyuiopasdfghjklzxcvbnm"
    string = string.lower()
    for x in string:
            for y in check:
                if x == y:
                    check = [q for q in check if q != y] 
    if check == []:
        return True
    else:
        return False


#your code here

# %%
check = "qwertyuiopasdfghjklzxcvbnm"
string = "Waltz, nymph, for quick jigs vex Bud."
r = False
string = string.lower()
for x in string:
        for y in check:
            if x == y:
                check = [q for q in check if q != y] 
                print(check)
if check == []:
    r = True
else:
    r = False
print(r)
# Out:
# ['q', 'e', 'r', 't', 'y', 'u', 'i', 'o', 'p', 'a', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'z', 'x', 'c', 'v', 'b', 'n', 'm']
# ['q', 'e', 'r', 't', 'y', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'z', 'x', 'c', 'v', 'b', 'n', 'm']
# ['q', 'e', 'r', 't', 'y', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'z', 'x', 'c', 'v', 'b', 'n', 'm']
# ['q', 'e', 'r', 'y', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'z', 'x', 'c', 'v', 'b', 'n', 'm']
# ['q', 'e', 'r', 'y', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'x', 'c', 'v', 'b', 'n', 'm']
# ['q', 'e', 'r', 'y', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'x', 'c', 'v', 'b', 'm']
# ['q', 'e', 'r', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'x', 'c', 'v', 'b', 'm']
# ['q', 'e', 'r', 'u', 'i', 'o', 'p', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'x', 'c', 'v', 'b']
# ['q', 'e', 'r', 'u', 'i', 'o', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'x', 'c', 'v', 'b']
# ...

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.027s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
#your code here
# Out:
#   Cell In[31], line 3
#
#     ^
# _IncompleteInputError: incomplete input

# %%
input_list = ["moon","mouse"]

n=1
suplist = []
output_list = []

word=0
letter=0

for item in input_list:
    while input_list[word][letter] == input_list[word+1][letter]:
        if input_list[word][letter+1]:
            letter+=1
        else:
            print(input_list[word])
            word = 1
    if input_list[word][letter] < input_list[word+1][letter]:
        print(input_list[word])
    if input_list[word][letter] > input_list[word+1][letter]:
        print(input_list[word+1])
# Out:
# moon
# moon

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
#your code here

# %%
# This will test your function 
test_pass(check_pass)
